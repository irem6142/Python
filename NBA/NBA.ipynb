# %%
import pandas as pd

# %%
df=pd.read_csv("nba.csv")

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ### İlk 10 kaydı getir

# %%
df.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %% [markdown]
# ### Toplam kaç kayıt vardır?

# %%
df.count()
# Out:
# Name        457
# Team        457
# Number      457
# Position    457
# Age         457
# Height      457
# Weight      457
# College     373
# Salary      446
# dtype: int64

# %%
len(df.index)
# Out:
# 458

# %% [markdown]
# ### Oyuncuların toplam maaş ortalaması

# %%
df["Salary"].mean()
# Out:
# 4842684.105381166

# %% [markdown]
# ### En yüksek maaş

# %%
df["Salary"].max()
# Out:
# 25000000.0

# %% [markdown]
# ### En yüksek maaşı alan kimdir

# %%
df.loc[df["Salary"]==25000000,"Name"]
# Out:
# 109    Kobe Bryant
# Name: Name, dtype: object

# %%
df.loc[df["Name"]=="Kobe Bryant","Age"]
# Out:
# 109    37.0
# Name: Age, dtype: float64

# %%
df[df["Salary"]==df["Salary"].max()]["Name"].iloc[0]
# Out:
# 'Kobe Bryant'

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ### Yaşı 20-25 arasında olan oyuncuların isim ve oynadıkları takım

# %%
df.loc[(df["Age"]>=20) & (df["Age"]<25)][["Name","Team","Age"]].sort_values("Age")
# Out:
#                         Name                Team   Age
# 377          Kelly Oubre Jr.  Washington Wizards  20.0
# 192          Stanley Johnson     Detroit Pistons  20.0
# 208             Myles Turner      Indiana Pacers  20.0
# 116         D'Angelo Russell  Los Angeles Lakers  20.0
# 452               Trey Lyles           Utah Jazz  20.0
# ..                       ...                 ...   ...
# 252           Terrence Jones     Houston Rockets  24.0
# 219          Khris Middleton     Milwaukee Bucks  24.0
# 213  Michael Carter-Williams     Milwaukee Bucks  24.0
# 310         Tim Hardaway Jr.       Atlanta Hawks  24.0
# 454                Raul Neto           Utah Jazz  24.0
#
# [152 rows x 3 columns]

# %%
df[(df["Age"]>=20)& (df["Age"]<25)][["Name","Team"]]
# Out:
#                 Name            Team
# 3        R.J. Hunter  Boston Celtics
# 6      Jordan Mickey  Boston Celtics
# 8       Terry Rozier  Boston Celtics
# 9       Marcus Smart  Boston Celtics
# 10   Jared Sullinger  Boston Celtics
# ..               ...             ...
# 446   Derrick Favors       Utah Jazz
# 447      Rudy Gobert       Utah Jazz
# 449      Rodney Hood       Utah Jazz
# 452       Trey Lyles       Utah Jazz
# 454        Raul Neto       Utah Jazz
#
# [152 rows x 2 columns]

# %% [markdown]
# ### John Holland'ın oynadığı takım

# %%
df.loc[df["Name"]=="John Holland","Team"]
# Out:
# 2    Boston Celtics
# Name: Team, dtype: object

# %%
df[df["Name"]=="John Holland"]["Team"].iloc[0]
# Out:
# 'Boston Celtics'

# %% [markdown]
# ### Takımlara göre oyuncuların ort maaşı

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.groupby("Team")["Salary"].mean()
# Out:
# Team
# Atlanta Hawks             4.860197e+06
# Boston Celtics            4.181505e+06
# Brooklyn Nets             3.501898e+06
# Charlotte Hornets         5.222728e+06
# Chicago Bulls             5.785559e+06
# Cleveland Cavaliers       7.642049e+06
# Dallas Mavericks          4.746582e+06
# Denver Nuggets            4.294424e+06
# Detroit Pistons           4.477884e+06
# Golden State Warriors     5.924600e+06
# Houston Rockets           5.018868e+06
# Indiana Pacers            4.450122e+06
# Los Angeles Clippers      6.323643e+06
# Los Angeles Lakers        4.784695e+06
# Memphis Grizzlies         5.467920e+06
# Miami Heat                6.347359e+06
# Milwaukee Bucks           4.350220e+06
# Minnesota Timberwolves    4.593054e+06
# New Orleans Pelicans      4.355304e+06
# New York Knicks           4.581494e+06
# Oklahoma City Thunder     6.251020e+06
# Orlando Magic             4.297248e+06
# Philadelphia 76ers        2.213778e+06
# Phoenix Suns              4.229676e+06
# ...

# %%
df.groupby("Team").mean()["Salary"]
# Out:
# C:\Users\iremu\AppData\Local\Temp\ipykernel_24756\1638942891.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Team").mean()["Salary"]
# Team
# Atlanta Hawks             4.860197e+06
# Boston Celtics            4.181505e+06
# Brooklyn Nets             3.501898e+06
# Charlotte Hornets         5.222728e+06
# Chicago Bulls             5.785559e+06
# Cleveland Cavaliers       7.642049e+06
# Dallas Mavericks          4.746582e+06
# Denver Nuggets            4.294424e+06
# Detroit Pistons           4.477884e+06
# Golden State Warriors     5.924600e+06
# Houston Rockets           5.018868e+06
# Indiana Pacers            4.450122e+06
# Los Angeles Clippers      6.323643e+06
# Los Angeles Lakers        4.784695e+06
# Memphis Grizzlies         5.467920e+06
# ...

# %% [markdown]
# ### Kaç Farklı takım mevcut

# %%
df["Team"].nunique()
# Out:
# 30

# %%
len(df.groupby("Team"))
# Out:
# 30

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ### Her takımda kaç oyuncu oynamaktadır

# %%
df.groupby("Team")["Name"].count()
# Out:
# Team
# Atlanta Hawks             15
# Boston Celtics            15
# Brooklyn Nets             15
# Charlotte Hornets         15
# Chicago Bulls             15
# Cleveland Cavaliers       15
# Dallas Mavericks          15
# Denver Nuggets            15
# Detroit Pistons           15
# Golden State Warriors     15
# Houston Rockets           15
# Indiana Pacers            15
# Los Angeles Clippers      15
# Los Angeles Lakers        15
# Memphis Grizzlies         18
# Miami Heat                15
# Milwaukee Bucks           16
# Minnesota Timberwolves    14
# New Orleans Pelicans      19
# New York Knicks           16
# Oklahoma City Thunder     15
# Orlando Magic             14
# Philadelphia 76ers        15
# Phoenix Suns              15
# Portland Trail Blazers    15
# Sacramento Kings          15
# San Antonio Spurs         15
# Toronto Raptors           15
# Utah Jazz                 15
# Washington Wizards        15
# Name: Name, dtype: int64

# %%
df["Team"].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Dallas Mavericks          15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Utah Jazz                 15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: Team, dtype: int64

# %% [markdown]
# ### İsminde and geçen

# %%
df[df["Name"].str.contains("and",na=False)]
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 2        John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 46        Elton Brand      Philadelphia 76ers    42.0       PF  37.0    6-9
# 52        Carl Landry      Philadelphia 76ers     7.0       PF  32.0    6-9
# 76    Leandro Barbosa   Golden State Warriors    19.0       SG  33.0    6-3
# 87       Brandon Rush   Golden State Warriors     4.0       SF  30.0    6-6
# 94     Branden Dawson    Los Angeles Clippers    22.0       SF  23.0    6-6
# 106      Brandon Bass      Los Angeles Lakers     2.0       PF  31.0    6-8
# 115     Julius Randle      Los Angeles Lakers    30.0       PF  21.0    6-9
# 124    Tyson Chandler            Phoenix Suns     4.0        C  33.0    7-1
# 127    Brandon Knight            Phoenix Suns     3.0       PG  24.0    6-3
# 149     Eric Moreland        Sacramento Kings    25.0       PF  24.0   6-10
# ...

# %%
df=df.dropna()

# %%
df[df["Name"].str.contains("and")]
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 52        Carl Landry      Philadelphia 76ers     7.0       PF  32.0    6-9
# 87       Brandon Rush   Golden State Warriors     4.0       SF  30.0    6-6
# 94     Branden Dawson    Los Angeles Clippers    22.0       SF  23.0    6-6
# 106      Brandon Bass      Los Angeles Lakers     2.0       PF  31.0    6-8
# 115     Julius Randle      Los Angeles Lakers    30.0       PF  21.0    6-9
# 127    Brandon Knight            Phoenix Suns     3.0       PG  24.0    6-3
# 149     Eric Moreland        Sacramento Kings    25.0       PF  24.0   6-10
# 238  Chandler Parsons        Dallas Mavericks    25.0       SF  27.0   6-10
# 271     Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 274    Brandan Wright       Memphis Grizzlies    34.0       PF  28.0   6-10
# 291   Orlando Johnson    New Orleans Pelicans     0.0       SG  27.0    6-5
# ...

# %%
def find_and(name):
    if "and" in name.lower():
        return True    
    return False

# %%
df[df["Name"].apply(find_and)]
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 52        Carl Landry      Philadelphia 76ers     7.0       PF  32.0    6-9
# 78       Andrew Bogut   Golden State Warriors    12.0        C  31.0    7-0
# 83     Andre Iguodala   Golden State Warriors     9.0       SF  32.0    6-6
# 87       Brandon Rush   Golden State Warriors     4.0       SF  30.0    6-6
# 94     Branden Dawson    Los Angeles Clippers    22.0       SF  23.0    6-6
# 98     DeAndre Jordan    Los Angeles Clippers     6.0        C  27.0   6-11
# 106      Brandon Bass      Los Angeles Lakers     2.0       PF  31.0    6-8
# 115     Julius Randle      Los Angeles Lakers    30.0       PF  21.0    6-9
# 127    Brandon Knight            Phoenix Suns     3.0       PG  24.0    6-3
# 137    James Anderson        Sacramento Kings     5.0       SG  27.0    6-6
# 149     Eric Moreland        Sacramento Kings    25.0       PF  24.0   6-10
# ...
